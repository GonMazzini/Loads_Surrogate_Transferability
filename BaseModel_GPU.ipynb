# %% [markdown]
# <a href="https://colab.research.google.com/github/GonMazzini/Loads_Surrogate_Transferability/blob/main/BaseModel_GPU.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# % Saved 13/3/2022
# - This notebook contains the implementation of the "baseline" model. Additionally, the model and the tensors are converted to cuda to allow running on gpu.

# %%
import pandas as pd 
import numpy as np
import math
from random import shuffle

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from tqdm import tqdm

# %%
if torch.cuda.is_available():
    device = torch.device("cuda:0")
    print("GPU")
else:
    device = torch.device("cpu")
    print("CPU")
# Out:
# GPU

# %% [markdown]
# # 0- Read the data as a data frame

# %%
df = pd.read_excel('LoadsDataBase_6D_Set123_FiltMinMaxCrit.xlsx') # Average the values from Set1,Set2 and Set3.
df.head(2)
# 0 : TT_Mx_avg
# 1 : TT_My_avg
# 2 : TB_Mx_avg
# 3 : TB_My_avg
# 4 : MS_Mz_avg
# 5 : BR_Mx_avg
# 6 : BR_My_avg
# 7 : TT-Mz_avg
# Out:
#    Unnamed: 0  pointno          U    SigmaU     Alpha      MannL  MannGamma  \
# 0           0        1   4.000000  0.100000 -0.650000   7.500000   1.000000
# 1           1        2  10.150758  1.208656 -0.139692  48.470634   1.363636
#
#    VeerDeltaPhi    TT_Mx_avg   TT_My_avg     TB_Mx_avg    TB_My_avg  \
# 0    -22.250000   747.561872  200.666288   6708.717789  8861.885588
# 1     -4.771217  3556.031457  676.339081  16692.647572  6329.099515
#
#      TT_Mz_avg    MS_Mz_avg     BR_Mx_avg     BR_My_avg
# 0   819.209904    63.457528   4253.317748  15006.726860
# 1  3746.460605  1354.995442  10409.290476  16289.414152

# %% [markdown]
# # ============================================================
# # ==========================Section 1 ==========================
# # ============================================================

# %%
X = df.iloc[:,2:8]
y = df.iloc[:,8:]

# %%
# Test split:
X, X_test, y, y_test = train_test_split(X,y, test_size = 0.2, shuffle = True,  random_state = 101)

print(f'The filtered data set consits on: {len(df)} entries.')
print(f'A total of {len(X)} will be used for training and validation.')
print(f'A total of {len(X_test)} will be used for testing the final model.')
# Out:
# The filtered data set consits on: 7664 entries.
# A total of 6131 will be used for training and validation.
# A total of 1533 will be used for testing the final model.

# %% [markdown]
# ### From now on, "X" and "y" will be used for train-validate the model.

# %%
feature_range = (0, 1)
scaler_x = preprocessing.MinMaxScaler(feature_range=feature_range).fit(X)
X_scaled = scaler_x.transform(X)

# %% [markdown]
# ### Separte between train and validation

# %%
X_train, X_val, y_train, y_val = train_test_split(X_scaled,y.values, test_size = 0.2, shuffle = True,  random_state = 101)

# printing number of samples for train-validation-test
print(f'A total of {y_train.shape[0]} for training, {round(100*y_train.shape[0]/len(df),1)} % of total data')
print(f'A total of {y_val.shape[0]} for validation, {round(100*y_val.shape[0]/len(df),1)} % of total data')
print(f'A total of {y_test.shape[0]} for testing, {round(100*y_test.shape[0]/len(df),1)} % of total data')
# Out:
# A total of 4904 for training, 64.0 % of total data
# A total of 1227 for validation, 16.0 % of total data
# A total of 1533 for testing, 20.0 % of total data

# %% [markdown]
# ### The PyTorch worfklow can be summarized as follows:
# - 1) Design model (input, output size, forward pass)
# - 2) Construct loss and optimizer
# - 3) Training loop
#    - forward pass: compute prediction based on the current weights and biases of the net
#    - backward pass: compute the gradients of the loss function wrt. to model parameters
#    - update weigths in

# %%
input_size = 6             # np.shape(X_train)[1]
output_channels = 8        # np.shape(y_train)[1]
num_hid_1 = 50
num_hid_2 = 50

# %%
class Net(nn.Module):
    
    def __init__(self, num_hid_1, num_hid_2):   
        super(Net,self).__init__()  # inherit from the superclass Module
        self.num_hid_1 = num_hid_1
        self.num_hid_2 = num_hid_2
        
        self.fc1 = nn.Linear(in_features= input_size,
                             out_features= self.num_hid_1,                             
                            bias = True)  
        
        self.fc2 = nn.Linear(in_features = self.num_hid_1, 
                             out_features = self.num_hid_2,
                            bias = True)
        
        self.fc3 = nn.Linear(in_features = self.num_hid_2, 
                             out_features = output_channels,
                            bias = True)
        
#        self.dropout = nn.Dropout(p=0.15)
        
    def forward(self,x):
        
        out = self.fc1(x)  
#        out = self.dropout(out)
        out = F.relu(out)
        out = self.fc2(out)
#        out = self.dropout(out)
        out = F.relu(out)
        out = self.fc3(out)                       #  torch.tanh(self.fc3(out))
        
        return out

# %%
# instantiate the class
model = Net(num_hid_1,num_hid_2)

# if torch.cuda.is_available():
#   model.to(device)

# Define the loss function (mean square error)
loss = nn.MSELoss()

# Instantiate optimizer passing the net parameters as argument, and learning rate
optimizer = optim.Adam(model.parameters(), lr = 0.01)

# list to store results
train_losses , val_losses= [],[]

# %%
# Try a dummy forward
#model(torch.tensor(X_train[0]).float().to(device))  # beware that need to convert from double to float

# %% [markdown]
# # 2.1- Use the PyTorch DataLoader and Dataset utils.
# - DataLoader class combines a dataset and a sampler, and provides an iterable over the given dataset for training the model
# - Dataset: just an abstract class representing a :class:`Dataset`

# %%
class FatigueLoads_TrainSet(Dataset):

    def __init__(self):
        self.n_samples = X_train.shape[0]
        self.x_data = torch.from_numpy(X_train) # size [n_samples, n_features]
        self.y_data = torch.from_numpy(y_train) # size [n_samples, 1]

    # support indexing such that dataset[i] can be used to get i-th sample
    def __getitem__(self, index):
        return self.x_data[index], self.y_data[index]

    # we can call len(dataset) to return the size
    def __len__(self):
        return self.n_samples
    
class FatigueLoads_ValidationSet(Dataset):

    def __init__(self):
        self.n_samples = X_val.shape[0]
        self.x_data = torch.from_numpy(X_val) # size [n_samples, n_features]
        self.y_data = torch.from_numpy(y_val) # size [n_samples, 1]

    # support indexing such that dataset[i] can be used to get i-th sample
    def __getitem__(self, index):
        return self.x_data[index], self.y_data[index]

    # we can call len(dataset) to return the size
    def __len__(self):
        return self.n_samples

# %% [markdown]
# ### Get first sample and unpack. Note that the enviromental inputs are normalized using MinMaxScaler

# %%
train_dataset = FatigueLoads_TrainSet()
valid_dataset = FatigueLoads_ValidationSet()

first_data = train_dataset[0]
features, loads = first_data
print(features, loads)
# Out:
# tensor([0.9213, 0.5395, 0.2971, 0.1574, 0.7369, 0.3075], dtype=torch.float64) tensor([ 7116.1376,   808.7441, 21966.9989, 16383.7768,  7347.3186,   807.4632,
#         18567.6736, 16935.8620], dtype=torch.float64)

# %%
batch_size = X_val.shape[0]//8
num_epochs = 8

num_batches_train = X_train.shape[0] // batch_size
num_batches_test = X_val.shape[0] // batch_size

print(f'Num batches train: {num_batches_train}')
print(f'Num batches valid: {num_batches_test}')
train_loader = DataLoader(dataset=train_dataset,
                          batch_size=batch_size,
                          shuffle=True,
                          num_workers=0)

valid_loader = DataLoader(dataset=valid_dataset,
                          batch_size=batch_size,
                          shuffle=True,
                          num_workers=0)
# Out:
# Num batches train: 32
# Num batches valid: 8

# %% [markdown]
# # 3.1- Start training loop

# %%
ErrorOnPUPOSE
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-a9d414c362a2> in <module>()
# ----> 1 ErrorOnPUPOSE
#
# NameError: name 'ErrorOnPUPOSE' is not defined

# %%
torch.cuda.memory_allocated(device)
# Out:
# 0

# %%
15360.00 + 560640.00 
# batch: 0, Memory After forward 576000.00 MB
# batch: 0, Memory consuming by forward 560640.00 MB

# %%
# %%time

print(f'initial memory {torch.cuda.memory_allocated(device)/(1024*1024*8):.4f}')
# /(1024*1024*8)
if torch.cuda.is_available():
  model.to(device)
  print(f' memory after device {torch.cuda.memory_allocated(device)/(1024*1024*8):.4f}')
# /(1024*1024*8)
for epoch in range(num_epochs):
    
    model.train()
    print(f'Begin epoch: {epoch}')
    for i, (inputs, loads) in enumerate(train_loader):
        #print(features, loads)
        
        optimizer.zero_grad()                      # zeroize accumulated gradients in parameters 
        a = torch.cuda.memory_allocated(device)/(1024*1024*8) #/(1024*1024*8)            
        print(f'batch: {i}, memory Before forward {a:.2f} MB')
        output = model(inputs.float().to(device))             # forwards pass       
        b = torch.cuda.memory_allocated(device)/(1024*1024*8) #/(1024*1024*8)   
        print(f'batch: {i}, Memory After forward {b:.2f} MB')
        c = (b-a) # NO NEED TO DIVIDE again
        print(f'batch: {i}, Memory consuming by forward {c:.4f} MB')
        batch_loss = loss(output, loads.float().to(device))   # compute loss for current batch
        
        batch_loss.backward()                      # compute the gradient of the loss wrt. model parameters
        d = torch.cuda.memory_allocated(device)/(1024*1024*8) #/(1024*1024*8)  
        print(f'batch: {i}, Memory After backward {d:.4f} MB')
        optimizer.step()                           # update weights according to the comptued gradients
        e = torch.cuda.memory_allocated(device)/(1024*1024*8) #/(1024*1024*8) 
        print(f'batch: {i}, Memory After optimizer step {e:.4f} MB')
    
    epoch_loss_train = 0
    epoch_loss_test = 0
    model.eval()
    
    ##### Evaluate training
    for i, (inputs, loads) in enumerate(train_loader):
        
        output = model(inputs.float().to(device))
        
        batch_loss_train = loss(output, loads.float().to(device))  # compute loss for the current batch
        epoch_loss_train += batch_loss_train            # accumulate loss for the current epoch
        
        #print(f'Epoch: {epoch+1}/{num_epochs}  | Step {i+1}/{n_iterations}')
    
    ##### Evaluate validation    
    for i, (inputs, loads) in enumerate(valid_loader):
        
        output = model(inputs.float().to(device))
        
        batch_loss_test = loss(output, loads.float().to(device))  # compute loss for the current batch
        epoch_loss_test += batch_loss_test     # accumulate loss for the current epoch
        
        #print(f'Epoch: {epoch+1}/{num_epochs}  | Step {i+1}/{n_iterations}')
    
    if epoch % 1 == 0: 
        print(f'Epoch: {epoch+1}/{num_epochs} | Train loss: {epoch_loss_train/num_batches_train}       | Val loss {epoch_loss_test/num_batches_test}')
        
    # store in list for plotting the loss per epoch    
    val_losses.append(epoch_loss_test.cpu().detach().numpy()/num_batches_test)  
    train_losses.append(epoch_loss_train.cpu().detach().numpy()/num_batches_train)
# Out:
# initial memory 0.3688
#  memory after device 0.3688
# Begin epoch: 0
# batch: 0, memory Before forward 0.37 MB
# batch: 0, Memory After forward 0.38 MB
# batch: 0, Memory consuming by forward 0.0084 MB
# batch: 0, Memory After backward 0.3695 MB
# batch: 0, Memory After optimizer step 0.3695 MB
# batch: 1, memory Before forward 0.37 MB
# batch: 1, Memory After forward 0.38 MB
# batch: 1, Memory consuming by forward 0.0078 MB
# batch: 1, Memory After backward 0.3695 MB
# batch: 1, Memory After optimizer step 0.3695 MB
# batch: 2, memory Before forward 0.37 MB
# batch: 2, Memory After forward 0.38 MB
# batch: 2, Memory consuming by forward 0.0078 MB
# batch: 2, Memory After backward 0.3695 MB
# batch: 2, Memory After optimizer step 0.3695 MB
# batch: 3, memory Before forward 0.37 MB
# batch: 3, Memory After forward 0.38 MB
# batch: 3, Memory consuming by forward 0.0078 MB
# batch: 3, Memory After backward 0.3695 MB
# batch: 3, Memory After optimizer step 0.3695 MB
# batch: 4, memory Before forward 0.37 MB
# batch: 4, Memory After forward 0.38 MB
# batch: 4, Memory consuming by forward 0.0078 MB
# batch: 4, Memory After backward 0.3695 MB
# batch: 4, Memory After optimizer step 0.3695 MB
# batch: 5, memory Before forward 0.37 MB
# batch: 5, Memory After forward 0.38 MB
# batch: 5, Memory consuming by forward 0.0078 MB
# batch: 5, Memory After backward 0.3695 MB
# batch: 5, Memory After optimizer step 0.3695 MB
# batch: 6, memory Before forward 0.37 MB
# batch: 6, Memory After forward 0.38 MB
# batch: 6, Memory consuming by forward 0.0084 MB
# batch: 6, Memory After backward 0.3701 MB
# batch: 6, Memory After optimizer step 0.3701 MB
# batch: 7, memory Before forward 0.37 MB
# batch: 7, Memory After forward 0.38 MB
# batch: 7, Memory consuming by forward 0.0078 MB
# batch: 7, Memory After backward 0.3701 MB
# batch: 7, Memory After optimizer step 0.3701 MB
# batch: 8, memory Before forward 0.37 MB
# batch: 8, Memory After forward 0.38 MB
# batch: 8, Memory consuming by forward 0.0078 MB
# batch: 8, Memory After backward 0.3701 MB
# batch: 8, Memory After optimizer step 0.3701 MB
# batch: 9, memory Before forward 0.37 MB
# batch: 9, Memory After forward 0.38 MB
# batch: 9, Memory consuming by forward 0.0078 MB
# batch: 9, Memory After backward 0.3701 MB
# batch: 9, Memory After optimizer step 0.3701 MB
# batch: 10, memory Before forward 0.37 MB
# batch: 10, Memory After forward 0.38 MB
# batch: 10, Memory consuming by forward 0.0078 MB
# batch: 10, Memory After backward 0.3701 MB
# batch: 10, Memory After optimizer step 0.3701 MB
# batch: 11, memory Before forward 0.37 MB
# batch: 11, Memory After forward 0.38 MB
# batch: 11, Memory consuming by forward 0.0078 MB
# batch: 11, Memory After backward 0.3701 MB
# batch: 11, Memory After optimizer step 0.3701 MB
# batch: 12, memory Before forward 0.37 MB
# batch: 12, Memory After forward 0.38 MB
# batch: 12, Memory consuming by forward 0.0078 MB
# batch: 12, Memory After backward 0.3701 MB
# batch: 12, Memory After optimizer step 0.3701 MB
# batch: 13, memory Before forward 0.37 MB
# batch: 13, Memory After forward 0.38 MB
# batch: 13, Memory consuming by forward 0.0078 MB
# batch: 13, Memory After backward 0.3701 MB
# batch: 13, Memory After optimizer step 0.3701 MB
# batch: 14, memory Before forward 0.37 MB
# batch: 14, Memory After forward 0.38 MB
# batch: 14, Memory consuming by forward 0.0078 MB
# batch: 14, Memory After backward 0.3701 MB
# batch: 14, Memory After optimizer step 0.3701 MB
# batch: 15, memory Before forward 0.37 MB
# batch: 15, Memory After forward 0.38 MB
# batch: 15, Memory consuming by forward 0.0078 MB
# batch: 15, Memory After backward 0.3701 MB
# batch: 15, Memory After optimizer step 0.3701 MB
# batch: 16, memory Before forward 0.37 MB
# batch: 16, Memory After forward 0.38 MB
# batch: 16, Memory consuming by forward 0.0078 MB
# batch: 16, Memory After backward 0.3701 MB
# batch: 16, Memory After optimizer step 0.3701 MB
# batch: 17, memory Before forward 0.37 MB
# batch: 17, Memory After forward 0.38 MB
# batch: 17, Memory consuming by forward 0.0078 MB
# batch: 17, Memory After backward 0.3701 MB
# batch: 17, Memory After optimizer step 0.3701 MB
# batch: 18, memory Before forward 0.37 MB
# batch: 18, Memory After forward 0.38 MB
# batch: 18, Memory consuming by forward 0.0078 MB
# batch: 18, Memory After backward 0.3701 MB
# batch: 18, Memory After optimizer step 0.3701 MB
# batch: 19, memory Before forward 0.37 MB
# batch: 19, Memory After forward 0.38 MB
# batch: 19, Memory consuming by forward 0.0078 MB
# batch: 19, Memory After backward 0.3701 MB
# batch: 19, Memory After optimizer step 0.3701 MB
# batch: 20, memory Before forward 0.37 MB
# batch: 20, Memory After forward 0.38 MB
# batch: 20, Memory consuming by forward 0.0078 MB
# batch: 20, Memory After backward 0.3701 MB
# batch: 20, Memory After optimizer step 0.3701 MB
# batch: 21, memory Before forward 0.37 MB
# batch: 21, Memory After forward 0.38 MB
# batch: 21, Memory consuming by forward 0.0078 MB
# batch: 21, Memory After backward 0.3701 MB
# batch: 21, Memory After optimizer step 0.3701 MB
# batch: 22, memory Before forward 0.37 MB
# batch: 22, Memory After forward 0.38 MB
# batch: 22, Memory consuming by forward 0.0078 MB
# batch: 22, Memory After backward 0.3701 MB
# batch: 22, Memory After optimizer step 0.3701 MB
# batch: 23, memory Before forward 0.37 MB
# batch: 23, Memory After forward 0.38 MB
# batch: 23, Memory consuming by forward 0.0078 MB
# batch: 23, Memory After backward 0.3701 MB
# batch: 23, Memory After optimizer step 0.3701 MB
# batch: 24, memory Before forward 0.37 MB
# batch: 24, Memory After forward 0.38 MB
# batch: 24, Memory consuming by forward 0.0078 MB
# batch: 24, Memory After backward 0.3701 MB
# batch: 24, Memory After optimizer step 0.3701 MB
# batch: 25, memory Before forward 0.37 MB
# batch: 25, Memory After forward 0.38 MB
# batch: 25, Memory consuming by forward 0.0078 MB
# batch: 25, Memory After backward 0.3701 MB
# batch: 25, Memory After optimizer step 0.3701 MB
# batch: 26, memory Before forward 0.37 MB
# batch: 26, Memory After forward 0.38 MB
# batch: 26, Memory consuming by forward 0.0078 MB
# batch: 26, Memory After backward 0.3701 MB
# batch: 26, Memory After optimizer step 0.3701 MB
# batch: 27, memory Before forward 0.37 MB
# batch: 27, Memory After forward 0.38 MB
# batch: 27, Memory consuming by forward 0.0078 MB
# batch: 27, Memory After backward 0.3701 MB
# batch: 27, Memory After optimizer step 0.3701 MB
# batch: 28, memory Before forward 0.37 MB
# batch: 28, Memory After forward 0.38 MB
# batch: 28, Memory consuming by forward 0.0078 MB
# batch: 28, Memory After backward 0.3701 MB
# batch: 28, Memory After optimizer step 0.3701 MB
# batch: 29, memory Before forward 0.37 MB
# batch: 29, Memory After forward 0.38 MB
# batch: 29, Memory consuming by forward 0.0078 MB
# batch: 29, Memory After backward 0.3701 MB
# batch: 29, Memory After optimizer step 0.3701 MB
# batch: 30, memory Before forward 0.37 MB
# batch: 30, Memory After forward 0.38 MB
# batch: 30, Memory consuming by forward 0.0078 MB
# batch: 30, Memory After backward 0.3701 MB
# batch: 30, Memory After optimizer step 0.3701 MB
# batch: 31, memory Before forward 0.37 MB
# batch: 31, Memory After forward 0.38 MB
# batch: 31, Memory consuming by forward 0.0078 MB
# batch: 31, Memory After backward 0.3701 MB
# batch: 31, Memory After optimizer step 0.3701 MB
# batch: 32, memory Before forward 0.37 MB
# batch: 32, Memory After forward 0.37 MB
# batch: 32, Memory consuming by forward 0.0000 MB
# batch: 32, Memory After backward 0.3696 MB
# batch: 32, Memory After optimizer step 0.3696 MB
# Epoch: 1/8 | Train loss: 28665332.0       | Val loss 31935266.0
# Begin epoch: 1
# batch: 0, memory Before forward 0.73 MB
# batch: 0, Memory After forward 0.74 MB
# batch: 0, Memory consuming by forward 0.0084 MB
# batch: 0, Memory After backward 0.7328 MB
# batch: 0, Memory After optimizer step 0.7328 MB
# batch: 1, memory Before forward 0.73 MB
# batch: 1, Memory After forward 0.74 MB
# batch: 1, Memory consuming by forward 0.0078 MB
# batch: 1, Memory After backward 0.7328 MB
# batch: 1, Memory After optimizer step 0.7328 MB
# batch: 2, memory Before forward 0.73 MB
# batch: 2, Memory After forward 0.74 MB
# batch: 2, Memory consuming by forward 0.0078 MB
# batch: 2, Memory After backward 0.7328 MB
# batch: 2, Memory After optimizer step 0.7328 MB
# batch: 3, memory Before forward 0.73 MB
# batch: 3, Memory After forward 0.74 MB
# batch: 3, Memory consuming by forward 0.0078 MB
# batch: 3, Memory After backward 0.7328 MB
# batch: 3, Memory After optimizer step 0.7328 MB
# batch: 4, memory Before forward 0.73 MB
# batch: 4, Memory After forward 0.74 MB
# batch: 4, Memory consuming by forward 0.0078 MB
# batch: 4, Memory After backward 0.7328 MB
# batch: 4, Memory After optimizer step 0.7328 MB
# batch: 5, memory Before forward 0.73 MB
# batch: 5, Memory After forward 0.74 MB
# batch: 5, Memory consuming by forward 0.0078 MB
# batch: 5, Memory After backward 0.7328 MB
# batch: 5, Memory After optimizer step 0.7328 MB
# batch: 6, memory Before forward 0.73 MB
# batch: 6, Memory After forward 0.74 MB
# batch: 6, Memory consuming by forward 0.0078 MB
# batch: 6, Memory After backward 0.7328 MB
# batch: 6, Memory After optimizer step 0.7328 MB
# batch: 7, memory Before forward 0.73 MB
# batch: 7, Memory After forward 0.74 MB
# batch: 7, Memory consuming by forward 0.0078 MB
# batch: 7, Memory After backward 0.7328 MB
# batch: 7, Memory After optimizer step 0.7328 MB
# batch: 8, memory Before forward 0.73 MB
# batch: 8, Memory After forward 0.74 MB
# batch: 8, Memory consuming by forward 0.0078 MB
# batch: 8, Memory After backward 0.7328 MB
# batch: 8, Memory After optimizer step 0.7328 MB
# batch: 9, memory Before forward 0.73 MB
# batch: 9, Memory After forward 0.74 MB
# batch: 9, Memory consuming by forward 0.0078 MB
# batch: 9, Memory After backward 0.7328 MB
# batch: 9, Memory After optimizer step 0.7328 MB
# batch: 10, memory Before forward 0.73 MB
# batch: 10, Memory After forward 0.74 MB
# batch: 10, Memory consuming by forward 0.0078 MB
# batch: 10, Memory After backward 0.7328 MB
# batch: 10, Memory After optimizer step 0.7328 MB
# batch: 11, memory Before forward 0.73 MB
# batch: 11, Memory After forward 0.74 MB
# batch: 11, Memory consuming by forward 0.0078 MB
# batch: 11, Memory After backward 0.7328 MB
# batch: 11, Memory After optimizer step 0.7328 MB
# batch: 12, memory Before forward 0.73 MB
# batch: 12, Memory After forward 0.74 MB
# batch: 12, Memory consuming by forward 0.0078 MB
# batch: 12, Memory After backward 0.7328 MB
# batch: 12, Memory After optimizer step 0.7328 MB
# batch: 13, memory Before forward 0.73 MB
# batch: 13, Memory After forward 0.74 MB
# batch: 13, Memory consuming by forward 0.0078 MB
# batch: 13, Memory After backward 0.7328 MB
# batch: 13, Memory After optimizer step 0.7328 MB
# batch: 14, memory Before forward 0.73 MB
# batch: 14, Memory After forward 0.74 MB
# batch: 14, Memory consuming by forward 0.0078 MB
# batch: 14, Memory After backward 0.7328 MB
# batch: 14, Memory After optimizer step 0.3707 MB
# batch: 15, memory Before forward 0.37 MB
# batch: 15, Memory After forward 0.38 MB
# batch: 15, Memory consuming by forward 0.0084 MB
# batch: 15, Memory After backward 0.3713 MB
# batch: 15, Memory After optimizer step 0.3713 MB
# batch: 16, memory Before forward 0.37 MB
# batch: 16, Memory After forward 0.38 MB
# batch: 16, Memory consuming by forward 0.0078 MB
# batch: 16, Memory After backward 0.3713 MB
# batch: 16, Memory After optimizer step 0.3713 MB
# batch: 17, memory Before forward 0.37 MB
# batch: 17, Memory After forward 0.38 MB
# batch: 17, Memory consuming by forward 0.0078 MB
# batch: 17, Memory After backward 0.3713 MB
# batch: 17, Memory After optimizer step 0.3713 MB
# batch: 18, memory Before forward 0.37 MB
# batch: 18, Memory After forward 0.38 MB
# batch: 18, Memory consuming by forward 0.0078 MB
# batch: 18, Memory After backward 0.3713 MB
# batch: 18, Memory After optimizer step 0.3713 MB
# batch: 19, memory Before forward 0.37 MB
# batch: 19, Memory After forward 0.38 MB
# batch: 19, Memory consuming by forward 0.0078 MB
# batch: 19, Memory After backward 0.3713 MB
# batch: 19, Memory After optimizer step 0.3713 MB
# batch: 20, memory Before forward 0.37 MB
# batch: 20, Memory After forward 0.38 MB
# batch: 20, Memory consuming by forward 0.0078 MB
# batch: 20, Memory After backward 0.3713 MB
# batch: 20, Memory After optimizer step 0.3713 MB
# batch: 21, memory Before forward 0.37 MB
# batch: 21, Memory After forward 0.38 MB
# batch: 21, Memory consuming by forward 0.0078 MB
# batch: 21, Memory After backward 0.3713 MB
# batch: 21, Memory After optimizer step 0.3713 MB
# batch: 22, memory Before forward 0.37 MB
# batch: 22, Memory After forward 0.38 MB
# batch: 22, Memory consuming by forward 0.0078 MB
# batch: 22, Memory After backward 0.3713 MB
# batch: 22, Memory After optimizer step 0.3713 MB
# batch: 23, memory Before forward 0.37 MB
# batch: 23, Memory After forward 0.38 MB
# batch: 23, Memory consuming by forward 0.0078 MB
# batch: 23, Memory After backward 0.3713 MB
# batch: 23, Memory After optimizer step 0.3713 MB
# batch: 24, memory Before forward 0.37 MB
# batch: 24, Memory After forward 0.38 MB
# batch: 24, Memory consuming by forward 0.0078 MB
# batch: 24, Memory After backward 0.3713 MB
# batch: 24, Memory After optimizer step 0.3713 MB
# batch: 25, memory Before forward 0.37 MB
# batch: 25, Memory After forward 0.38 MB
# batch: 25, Memory consuming by forward 0.0078 MB
# batch: 25, Memory After backward 0.3713 MB
# batch: 25, Memory After optimizer step 0.3713 MB
# batch: 26, memory Before forward 0.37 MB
# batch: 26, Memory After forward 0.38 MB
# batch: 26, Memory consuming by forward 0.0078 MB
# batch: 26, Memory After backward 0.3713 MB
# batch: 26, Memory After optimizer step 0.3713 MB
# batch: 27, memory Before forward 0.37 MB
# batch: 27, Memory After forward 0.38 MB
# batch: 27, Memory consuming by forward 0.0078 MB
# batch: 27, Memory After backward 0.3713 MB
# batch: 27, Memory After optimizer step 0.3713 MB
# batch: 28, memory Before forward 0.37 MB
# batch: 28, Memory After forward 0.38 MB
# batch: 28, Memory consuming by forward 0.0078 MB
# batch: 28, Memory After backward 0.3713 MB
# batch: 28, Memory After optimizer step 0.3713 MB
# batch: 29, memory Before forward 0.37 MB
# batch: 29, Memory After forward 0.38 MB
# batch: 29, Memory consuming by forward 0.0078 MB
# batch: 29, Memory After backward 0.3713 MB
# batch: 29, Memory After optimizer step 0.3713 MB
# batch: 30, memory Before forward 0.37 MB
# batch: 30, Memory After forward 0.38 MB
# batch: 30, Memory consuming by forward 0.0078 MB
# batch: 30, Memory After backward 0.3713 MB
# batch: 30, Memory After optimizer step 0.3713 MB
# batch: 31, memory Before forward 0.37 MB
# batch: 31, Memory After forward 0.38 MB
# batch: 31, Memory consuming by forward 0.0078 MB
# batch: 31, Memory After backward 0.3713 MB
# batch: 31, Memory After optimizer step 0.3713 MB
# batch: 32, memory Before forward 0.37 MB
# batch: 32, Memory After forward 0.37 MB
# batch: 32, Memory consuming by forward 0.0000 MB
# batch: 32, Memory After backward 0.3708 MB
# batch: 32, Memory After optimizer step 0.3708 MB
# Epoch: 2/8 | Train loss: 27620560.0       | Val loss 29658888.0
# Begin epoch: 2
# batch: 0, memory Before forward 0.37 MB
# batch: 0, Memory After forward 0.38 MB
# batch: 0, Memory consuming by forward 0.0084 MB
# batch: 0, Memory After backward 0.3708 MB
# batch: 0, Memory After optimizer step 0.3708 MB
# batch: 1, memory Before forward 0.37 MB
# batch: 1, Memory After forward 0.38 MB
# batch: 1, Memory consuming by forward 0.0078 MB
# batch: 1, Memory After backward 0.3708 MB
# batch: 1, Memory After optimizer step 0.3708 MB
# batch: 2, memory Before forward 0.37 MB
# batch: 2, Memory After forward 0.38 MB
# batch: 2, Memory consuming by forward 0.0078 MB
# batch: 2, Memory After backward 0.3708 MB
# batch: 2, Memory After optimizer step 0.3708 MB
# batch: 3, memory Before forward 0.37 MB
# batch: 3, Memory After forward 0.38 MB
# batch: 3, Memory consuming by forward 0.0078 MB
# batch: 3, Memory After backward 0.3708 MB
# batch: 3, Memory After optimizer step 0.3708 MB
# batch: 4, memory Before forward 0.37 MB
# batch: 4, Memory After forward 0.38 MB
# batch: 4, Memory consuming by forward 0.0078 MB
# batch: 4, Memory After backward 0.3708 MB
# batch: 4, Memory After optimizer step 0.3708 MB
# batch: 5, memory Before forward 0.37 MB
# batch: 5, Memory After forward 0.38 MB
# batch: 5, Memory consuming by forward 0.0078 MB
# batch: 5, Memory After backward 0.3708 MB
# batch: 5, Memory After optimizer step 0.3708 MB
# batch: 6, memory Before forward 0.37 MB
# batch: 6, Memory After forward 0.38 MB
# batch: 6, Memory consuming by forward 0.0078 MB
# batch: 6, Memory After backward 0.3708 MB
# batch: 6, Memory After optimizer step 0.3708 MB
# batch: 7, memory Before forward 0.37 MB
# batch: 7, Memory After forward 0.38 MB
# batch: 7, Memory consuming by forward 0.0078 MB
# batch: 7, Memory After backward 0.3708 MB
# batch: 7, Memory After optimizer step 0.3708 MB
# batch: 8, memory Before forward 0.37 MB
# batch: 8, Memory After forward 0.38 MB
# batch: 8, Memory consuming by forward 0.0078 MB
# batch: 8, Memory After backward 0.3708 MB
# batch: 8, Memory After optimizer step 0.3708 MB
# batch: 9, memory Before forward 0.37 MB
# batch: 9, Memory After forward 0.38 MB
# batch: 9, Memory consuming by forward 0.0078 MB
# batch: 9, Memory After backward 0.3708 MB
# batch: 9, Memory After optimizer step 0.3708 MB
# batch: 10, memory Before forward 0.37 MB
# batch: 10, Memory After forward 0.38 MB
# batch: 10, Memory consuming by forward 0.0078 MB
# batch: 10, Memory After backward 0.3708 MB
# batch: 10, Memory After optimizer step 0.3708 MB
# batch: 11, memory Before forward 0.37 MB
# batch: 11, Memory After forward 0.38 MB
# batch: 11, Memory consuming by forward 0.0078 MB
# batch: 11, Memory After backward 0.3708 MB
# batch: 11, Memory After optimizer step 0.3708 MB
# batch: 12, memory Before forward 0.37 MB
# batch: 12, Memory After forward 0.38 MB
# batch: 12, Memory consuming by forward 0.0078 MB
# batch: 12, Memory After backward 0.3708 MB
# batch: 12, Memory After optimizer step 0.3708 MB
# batch: 13, memory Before forward 0.37 MB
# batch: 13, Memory After forward 0.38 MB
# batch: 13, Memory consuming by forward 0.0078 MB
# batch: 13, Memory After backward 0.3708 MB
# batch: 13, Memory After optimizer step 0.3708 MB
# batch: 14, memory Before forward 0.37 MB
# batch: 14, Memory After forward 0.38 MB
# batch: 14, Memory consuming by forward 0.0078 MB
# batch: 14, Memory After backward 0.3708 MB
# batch: 14, Memory After optimizer step 0.3708 MB
# batch: 15, memory Before forward 0.37 MB
# batch: 15, Memory After forward 0.38 MB
# batch: 15, Memory consuming by forward 0.0078 MB
# batch: 15, Memory After backward 0.3708 MB
# batch: 15, Memory After optimizer step 0.3708 MB
# batch: 16, memory Before forward 0.37 MB
# batch: 16, Memory After forward 0.38 MB
# batch: 16, Memory consuming by forward 0.0078 MB
# batch: 16, Memory After backward 0.3708 MB
# batch: 16, Memory After optimizer step 0.3708 MB
# batch: 17, memory Before forward 0.37 MB
# batch: 17, Memory After forward 0.38 MB
# batch: 17, Memory consuming by forward 0.0078 MB
# batch: 17, Memory After backward 0.3708 MB
# batch: 17, Memory After optimizer step 0.3708 MB
# batch: 18, memory Before forward 0.37 MB
# batch: 18, Memory After forward 0.38 MB
# batch: 18, Memory consuming by forward 0.0078 MB
# batch: 18, Memory After backward 0.3708 MB
# batch: 18, Memory After optimizer step 0.3708 MB
# batch: 19, memory Before forward 0.37 MB
# batch: 19, Memory After forward 0.38 MB
# batch: 19, Memory consuming by forward 0.0078 MB
# batch: 19, Memory After backward 0.3708 MB
# batch: 19, Memory After optimizer step 0.3708 MB
# batch: 20, memory Before forward 0.37 MB
# batch: 20, Memory After forward 0.38 MB
# batch: 20, Memory consuming by forward 0.0078 MB
# batch: 20, Memory After backward 0.3708 MB
# batch: 20, Memory After optimizer step 0.3708 MB
# batch: 21, memory Before forward 0.37 MB
# batch: 21, Memory After forward 0.38 MB
# batch: 21, Memory consuming by forward 0.0078 MB
# batch: 21, Memory After backward 0.3708 MB
# batch: 21, Memory After optimizer step 0.3708 MB
# batch: 22, memory Before forward 0.37 MB
# batch: 22, Memory After forward 0.38 MB
# batch: 22, Memory consuming by forward 0.0078 MB
# batch: 22, Memory After backward 0.3708 MB
# batch: 22, Memory After optimizer step 0.3708 MB
# batch: 23, memory Before forward 0.37 MB
# batch: 23, Memory After forward 0.38 MB
# batch: 23, Memory consuming by forward 0.0078 MB
# batch: 23, Memory After backward 0.3708 MB
# batch: 23, Memory After optimizer step 0.3708 MB
# batch: 24, memory Before forward 0.37 MB
# batch: 24, Memory After forward 0.38 MB
# batch: 24, Memory consuming by forward 0.0084 MB
# batch: 24, Memory After backward 0.3713 MB
# batch: 24, Memory After optimizer step 0.3713 MB
# batch: 25, memory Before forward 0.37 MB
# batch: 25, Memory After forward 0.38 MB
# batch: 25, Memory consuming by forward 0.0078 MB
# batch: 25, Memory After backward 0.3713 MB
# batch: 25, Memory After optimizer step 0.3713 MB
# batch: 26, memory Before forward 0.37 MB
# batch: 26, Memory After forward 0.38 MB
# batch: 26, Memory consuming by forward 0.0078 MB
# batch: 26, Memory After backward 0.3713 MB
# batch: 26, Memory After optimizer step 0.3713 MB
# batch: 27, memory Before forward 0.37 MB
# batch: 27, Memory After forward 0.38 MB
# batch: 27, Memory consuming by forward 0.0078 MB
# batch: 27, Memory After backward 0.3713 MB
# batch: 27, Memory After optimizer step 0.3713 MB
# batch: 28, memory Before forward 0.37 MB
# batch: 28, Memory After forward 0.38 MB
# batch: 28, Memory consuming by forward 0.0078 MB
# batch: 28, Memory After backward 0.3713 MB
# batch: 28, Memory After optimizer step 0.3713 MB
# batch: 29, memory Before forward 0.37 MB
# batch: 29, Memory After forward 0.38 MB
# batch: 29, Memory consuming by forward 0.0078 MB
# batch: 29, Memory After backward 0.3713 MB
# batch: 29, Memory After optimizer step 0.3713 MB
# batch: 30, memory Before forward 0.37 MB
# batch: 30, Memory After forward 0.38 MB
# batch: 30, Memory consuming by forward 0.0078 MB
# batch: 30, Memory After backward 0.3713 MB
# batch: 30, Memory After optimizer step 0.3713 MB
# batch: 31, memory Before forward 0.37 MB
# batch: 31, Memory After forward 0.38 MB
# batch: 31, Memory consuming by forward 0.0078 MB
# batch: 31, Memory After backward 0.3713 MB
# batch: 31, Memory After optimizer step 0.3713 MB
# batch: 32, memory Before forward 0.37 MB
# batch: 32, Memory After forward 0.37 MB
# batch: 32, Memory consuming by forward 0.0000 MB
# batch: 32, Memory After backward 0.3708 MB
# batch: 32, Memory After optimizer step 0.3708 MB
# Epoch: 3/8 | Train loss: 26599258.0       | Val loss 28378742.0
# Begin epoch: 3
# batch: 0, memory Before forward 0.73 MB
# batch: 0, Memory After forward 0.74 MB
# batch: 0, Memory consuming by forward 0.0084 MB
# batch: 0, Memory After backward 0.7340 MB
# batch: 0, Memory After optimizer step 0.7340 MB
# batch: 1, memory Before forward 0.73 MB
# batch: 1, Memory After forward 0.74 MB
# batch: 1, Memory consuming by forward 0.0078 MB
# batch: 1, Memory After backward 0.7340 MB
# batch: 1, Memory After optimizer step 0.7340 MB
# batch: 2, memory Before forward 0.73 MB
# batch: 2, Memory After forward 0.74 MB
# batch: 2, Memory consuming by forward 0.0078 MB
# batch: 2, Memory After backward 0.7340 MB
# batch: 2, Memory After optimizer step 0.7340 MB
# batch: 3, memory Before forward 0.73 MB
# batch: 3, Memory After forward 0.74 MB
# batch: 3, Memory consuming by forward 0.0078 MB
# batch: 3, Memory After backward 0.7340 MB
# batch: 3, Memory After optimizer step 0.7340 MB
# batch: 4, memory Before forward 0.73 MB
# batch: 4, Memory After forward 0.74 MB
# batch: 4, Memory consuming by forward 0.0078 MB
# batch: 4, Memory After backward 0.7340 MB
# batch: 4, Memory After optimizer step 0.7340 MB
# batch: 5, memory Before forward 0.73 MB
# batch: 5, Memory After forward 0.74 MB
# batch: 5, Memory consuming by forward 0.0078 MB
# batch: 5, Memory After backward 0.7340 MB
# batch: 5, Memory After optimizer step 0.7340 MB
# batch: 6, memory Before forward 0.73 MB
# batch: 6, Memory After forward 0.74 MB
# batch: 6, Memory consuming by forward 0.0078 MB
# batch: 6, Memory After backward 0.7340 MB
# batch: 6, Memory After optimizer step 0.7340 MB
# batch: 7, memory Before forward 0.73 MB
# batch: 7, Memory After forward 0.74 MB
# batch: 7, Memory consuming by forward 0.0078 MB
# batch: 7, Memory After backward 0.7340 MB
# batch: 7, Memory After optimizer step 0.7340 MB
# batch: 8, memory Before forward 0.73 MB
# batch: 8, Memory After forward 0.74 MB
# batch: 8, Memory consuming by forward 0.0078 MB
# batch: 8, Memory After backward 0.7340 MB
# batch: 8, Memory After optimizer step 0.7340 MB
# batch: 9, memory Before forward 0.73 MB
# batch: 9, Memory After forward 0.74 MB
# batch: 9, Memory consuming by forward 0.0078 MB
# batch: 9, Memory After backward 0.7340 MB
# batch: 9, Memory After optimizer step 0.7340 MB
# batch: 10, memory Before forward 0.73 MB
# batch: 10, Memory After forward 0.74 MB
# batch: 10, Memory consuming by forward 0.0078 MB
# batch: 10, Memory After backward 0.7340 MB
# batch: 10, Memory After optimizer step 0.7340 MB
# batch: 11, memory Before forward 0.37 MB
# batch: 11, Memory After forward 0.38 MB
# batch: 11, Memory consuming by forward 0.0084 MB
# batch: 11, Memory After backward 0.3713 MB
# batch: 11, Memory After optimizer step 0.3713 MB
# batch: 12, memory Before forward 0.37 MB
# batch: 12, Memory After forward 0.38 MB
# batch: 12, Memory consuming by forward 0.0078 MB
# batch: 12, Memory After backward 0.3713 MB
# batch: 12, Memory After optimizer step 0.3713 MB
# batch: 13, memory Before forward 0.37 MB
# batch: 13, Memory After forward 0.38 MB
# batch: 13, Memory consuming by forward 0.0078 MB
# batch: 13, Memory After backward 0.3713 MB
# batch: 13, Memory After optimizer step 0.3713 MB
# batch: 14, memory Before forward 0.37 MB
# batch: 14, Memory After forward 0.38 MB
# batch: 14, Memory consuming by forward 0.0078 MB
# batch: 14, Memory After backward 0.3713 MB
# batch: 14, Memory After optimizer step 0.3713 MB
# batch: 15, memory Before forward 0.37 MB
# batch: 15, Memory After forward 0.38 MB
# batch: 15, Memory consuming by forward 0.0078 MB
# batch: 15, Memory After backward 0.3713 MB
# batch: 15, Memory After optimizer step 0.3713 MB
# batch: 16, memory Before forward 0.37 MB
# batch: 16, Memory After forward 0.38 MB
# batch: 16, Memory consuming by forward 0.0078 MB
# batch: 16, Memory After backward 0.3713 MB
# batch: 16, Memory After optimizer step 0.3713 MB
# batch: 17, memory Before forward 0.37 MB
# batch: 17, Memory After forward 0.38 MB
# batch: 17, Memory consuming by forward 0.0078 MB
# batch: 17, Memory After backward 0.3713 MB
# batch: 17, Memory After optimizer step 0.3713 MB
# batch: 18, memory Before forward 0.37 MB
# batch: 18, Memory After forward 0.38 MB
# batch: 18, Memory consuming by forward 0.0078 MB
# batch: 18, Memory After backward 0.3713 MB
# batch: 18, Memory After optimizer step 0.3713 MB
# batch: 19, memory Before forward 0.37 MB
# batch: 19, Memory After forward 0.38 MB
# batch: 19, Memory consuming by forward 0.0078 MB
# batch: 19, Memory After backward 0.3713 MB
# batch: 19, Memory After optimizer step 0.3713 MB
# batch: 20, memory Before forward 0.37 MB
# batch: 20, Memory After forward 0.38 MB
# batch: 20, Memory consuming by forward 0.0078 MB
# batch: 20, Memory After backward 0.3713 MB
# batch: 20, Memory After optimizer step 0.3713 MB
# batch: 21, memory Before forward 0.37 MB
# batch: 21, Memory After forward 0.38 MB
# batch: 21, Memory consuming by forward 0.0078 MB
# batch: 21, Memory After backward 0.3713 MB
# batch: 21, Memory After optimizer step 0.3713 MB
# batch: 22, memory Before forward 0.37 MB
# batch: 22, Memory After forward 0.38 MB
# batch: 22, Memory consuming by forward 0.0078 MB
# batch: 22, Memory After backward 0.3713 MB
# batch: 22, Memory After optimizer step 0.3713 MB
# batch: 23, memory Before forward 0.37 MB
# batch: 23, Memory After forward 0.38 MB
# batch: 23, Memory consuming by forward 0.0078 MB
# batch: 23, Memory After backward 0.3713 MB
# batch: 23, Memory After optimizer step 0.3713 MB
# batch: 24, memory Before forward 0.37 MB
# batch: 24, Memory After forward 0.38 MB
# batch: 24, Memory consuming by forward 0.0078 MB
# batch: 24, Memory After backward 0.3713 MB
# batch: 24, Memory After optimizer step 0.3713 MB
# batch: 25, memory Before forward 0.37 MB
# batch: 25, Memory After forward 0.38 MB
# batch: 25, Memory consuming by forward 0.0078 MB
# batch: 25, Memory After backward 0.3713 MB
# batch: 25, Memory After optimizer step 0.3713 MB
# batch: 26, memory Before forward 0.37 MB
# batch: 26, Memory After forward 0.38 MB
# batch: 26, Memory consuming by forward 0.0078 MB
# batch: 26, Memory After backward 0.3713 MB
# batch: 26, Memory After optimizer step 0.3713 MB
# batch: 27, memory Before forward 0.37 MB
# batch: 27, Memory After forward 0.38 MB
# batch: 27, Memory consuming by forward 0.0078 MB
# batch: 27, Memory After backward 0.3713 MB
# batch: 27, Memory After optimizer step 0.3713 MB
# batch: 28, memory Before forward 0.37 MB
# batch: 28, Memory After forward 0.38 MB
# batch: 28, Memory consuming by forward 0.0078 MB
# batch: 28, Memory After backward 0.3713 MB
# batch: 28, Memory After optimizer step 0.3713 MB
# batch: 29, memory Before forward 0.37 MB
# batch: 29, Memory After forward 0.38 MB
# batch: 29, Memory consuming by forward 0.0078 MB
# batch: 29, Memory After backward 0.3713 MB
# batch: 29, Memory After optimizer step 0.3713 MB
# batch: 30, memory Before forward 0.37 MB
# batch: 30, Memory After forward 0.38 MB
# batch: 30, Memory consuming by forward 0.0078 MB
# batch: 30, Memory After backward 0.3713 MB
# batch: 30, Memory After optimizer step 0.3713 MB
# batch: 31, memory Before forward 0.37 MB
# batch: 31, Memory After forward 0.38 MB
# batch: 31, Memory consuming by forward 0.0078 MB
# batch: 31, Memory After backward 0.3713 MB
# batch: 31, Memory After optimizer step 0.3713 MB
# batch: 32, memory Before forward 0.37 MB
# batch: 32, Memory After forward 0.37 MB
# batch: 32, Memory consuming by forward 0.0000 MB
# batch: 32, Memory After backward 0.3708 MB
# batch: 32, Memory After optimizer step 0.3708 MB
# Epoch: 4/8 | Train loss: 25600606.0       | Val loss 26345048.0
# Begin epoch: 4
# batch: 0, memory Before forward 0.37 MB
# batch: 0, Memory After forward 0.38 MB
# batch: 0, Memory consuming by forward 0.0084 MB
# batch: 0, Memory After backward 0.3713 MB
# batch: 0, Memory After optimizer step 0.3713 MB
# batch: 1, memory Before forward 0.37 MB
# batch: 1, Memory After forward 0.38 MB
# batch: 1, Memory consuming by forward 0.0078 MB
# batch: 1, Memory After backward 0.3713 MB
# batch: 1, Memory After optimizer step 0.3713 MB
# batch: 2, memory Before forward 0.37 MB
# batch: 2, Memory After forward 0.38 MB
# batch: 2, Memory consuming by forward 0.0078 MB
# batch: 2, Memory After backward 0.3713 MB
# batch: 2, Memory After optimizer step 0.3713 MB
# batch: 3, memory Before forward 0.37 MB
# batch: 3, Memory After forward 0.38 MB
# batch: 3, Memory consuming by forward 0.0078 MB
# batch: 3, Memory After backward 0.3713 MB
# batch: 3, Memory After optimizer step 0.3713 MB
# batch: 4, memory Before forward 0.37 MB
# batch: 4, Memory After forward 0.38 MB
# batch: 4, Memory consuming by forward 0.0078 MB
# batch: 4, Memory After backward 0.3713 MB
# batch: 4, Memory After optimizer step 0.3713 MB
# batch: 5, memory Before forward 0.37 MB
# batch: 5, Memory After forward 0.38 MB
# batch: 5, Memory consuming by forward 0.0078 MB
# batch: 5, Memory After backward 0.3713 MB
# batch: 5, Memory After optimizer step 0.3713 MB
# batch: 6, memory Before forward 0.37 MB
# batch: 6, Memory After forward 0.38 MB
# batch: 6, Memory consuming by forward 0.0078 MB
# batch: 6, Memory After backward 0.3713 MB
# batch: 6, Memory After optimizer step 0.3713 MB
# batch: 7, memory Before forward 0.37 MB
# batch: 7, Memory After forward 0.38 MB
# batch: 7, Memory consuming by forward 0.0078 MB
# batch: 7, Memory After backward 0.3713 MB
# batch: 7, Memory After optimizer step 0.3713 MB
# batch: 8, memory Before forward 0.37 MB
# batch: 8, Memory After forward 0.38 MB
# batch: 8, Memory consuming by forward 0.0078 MB
# batch: 8, Memory After backward 0.3713 MB
# batch: 8, Memory After optimizer step 0.3713 MB
# batch: 9, memory Before forward 0.37 MB
# batch: 9, Memory After forward 0.38 MB
# batch: 9, Memory consuming by forward 0.0078 MB
# batch: 9, Memory After backward 0.3713 MB
# batch: 9, Memory After optimizer step 0.3713 MB
# batch: 10, memory Before forward 0.37 MB
# batch: 10, Memory After forward 0.38 MB
# batch: 10, Memory consuming by forward 0.0078 MB
# batch: 10, Memory After backward 0.3713 MB
# batch: 10, Memory After optimizer step 0.3713 MB
# batch: 11, memory Before forward 0.37 MB
# batch: 11, Memory After forward 0.38 MB
# batch: 11, Memory consuming by forward 0.0078 MB
# batch: 11, Memory After backward 0.3713 MB
# batch: 11, Memory After optimizer step 0.3713 MB
# batch: 12, memory Before forward 0.37 MB
# batch: 12, Memory After forward 0.38 MB
# batch: 12, Memory consuming by forward 0.0078 MB
# batch: 12, Memory After backward 0.3713 MB
# batch: 12, Memory After optimizer step 0.3713 MB
# batch: 13, memory Before forward 0.37 MB
# batch: 13, Memory After forward 0.38 MB
# batch: 13, Memory consuming by forward 0.0078 MB
# batch: 13, Memory After backward 0.3713 MB
# batch: 13, Memory After optimizer step 0.3713 MB
# batch: 14, memory Before forward 0.37 MB
# batch: 14, Memory After forward 0.38 MB
# batch: 14, Memory consuming by forward 0.0078 MB
# batch: 14, Memory After backward 0.3713 MB
# batch: 14, Memory After optimizer step 0.3713 MB
# batch: 15, memory Before forward 0.37 MB
# batch: 15, Memory After forward 0.38 MB
# batch: 15, Memory consuming by forward 0.0078 MB
# batch: 15, Memory After backward 0.3713 MB
# batch: 15, Memory After optimizer step 0.3713 MB
# batch: 16, memory Before forward 0.37 MB
# batch: 16, Memory After forward 0.38 MB
# batch: 16, Memory consuming by forward 0.0078 MB
# batch: 16, Memory After backward 0.3713 MB
# batch: 16, Memory After optimizer step 0.3713 MB
# batch: 17, memory Before forward 0.37 MB
# batch: 17, Memory After forward 0.38 MB
# batch: 17, Memory consuming by forward 0.0078 MB
# batch: 17, Memory After backward 0.3713 MB
# batch: 17, Memory After optimizer step 0.3713 MB
# batch: 18, memory Before forward 0.37 MB
# batch: 18, Memory After forward 0.38 MB
# batch: 18, Memory consuming by forward 0.0078 MB
# batch: 18, Memory After backward 0.3713 MB
# batch: 18, Memory After optimizer step 0.3713 MB
# batch: 19, memory Before forward 0.37 MB
# batch: 19, Memory After forward 0.38 MB
# batch: 19, Memory consuming by forward 0.0078 MB
# batch: 19, Memory After backward 0.3713 MB
# batch: 19, Memory After optimizer step 0.3713 MB
# batch: 20, memory Before forward 0.37 MB
# batch: 20, Memory After forward 0.38 MB
# batch: 20, Memory consuming by forward 0.0084 MB
# batch: 20, Memory After backward 0.3713 MB
# batch: 20, Memory After optimizer step 0.3713 MB
# batch: 21, memory Before forward 0.37 MB
# batch: 21, Memory After forward 0.38 MB
# batch: 21, Memory consuming by forward 0.0078 MB
# batch: 21, Memory After backward 0.3713 MB
# batch: 21, Memory After optimizer step 0.3713 MB
# batch: 22, memory Before forward 0.37 MB
# batch: 22, Memory After forward 0.38 MB
# batch: 22, Memory consuming by forward 0.0078 MB
# batch: 22, Memory After backward 0.3713 MB
# batch: 22, Memory After optimizer step 0.3713 MB
# batch: 23, memory Before forward 0.37 MB
# batch: 23, Memory After forward 0.38 MB
# batch: 23, Memory consuming by forward 0.0078 MB
# batch: 23, Memory After backward 0.3713 MB
# batch: 23, Memory After optimizer step 0.3713 MB
# batch: 24, memory Before forward 0.37 MB
# batch: 24, Memory After forward 0.38 MB
# batch: 24, Memory consuming by forward 0.0078 MB
# batch: 24, Memory After backward 0.3713 MB
# batch: 24, Memory After optimizer step 0.3713 MB
# batch: 25, memory Before forward 0.37 MB
# batch: 25, Memory After forward 0.38 MB
# batch: 25, Memory consuming by forward 0.0078 MB
# batch: 25, Memory After backward 0.3713 MB
# batch: 25, Memory After optimizer step 0.3713 MB
# batch: 26, memory Before forward 0.37 MB
# batch: 26, Memory After forward 0.38 MB
# batch: 26, Memory consuming by forward 0.0078 MB
# batch: 26, Memory After backward 0.3713 MB
# batch: 26, Memory After optimizer step 0.3713 MB
# batch: 27, memory Before forward 0.37 MB
# batch: 27, Memory After forward 0.38 MB
# batch: 27, Memory consuming by forward 0.0078 MB
# batch: 27, Memory After backward 0.3713 MB
# batch: 27, Memory After optimizer step 0.3713 MB
# batch: 28, memory Before forward 0.37 MB
# batch: 28, Memory After forward 0.38 MB
# batch: 28, Memory consuming by forward 0.0078 MB
# batch: 28, Memory After backward 0.3713 MB
# batch: 28, Memory After optimizer step 0.3713 MB
# batch: 29, memory Before forward 0.37 MB
# batch: 29, Memory After forward 0.38 MB
# batch: 29, Memory consuming by forward 0.0078 MB
# batch: 29, Memory After backward 0.3713 MB
# batch: 29, Memory After optimizer step 0.3713 MB
# batch: 30, memory Before forward 0.37 MB
# batch: 30, Memory After forward 0.38 MB
# batch: 30, Memory consuming by forward 0.0078 MB
# batch: 30, Memory After backward 0.3713 MB
# batch: 30, Memory After optimizer step 0.3713 MB
# batch: 31, memory Before forward 0.37 MB
# batch: 31, Memory After forward 0.38 MB
# batch: 31, Memory consuming by forward 0.0078 MB
# batch: 31, Memory After backward 0.3713 MB
# batch: 31, Memory After optimizer step 0.3713 MB
# batch: 32, memory Before forward 0.37 MB
# batch: 32, Memory After forward 0.37 MB
# batch: 32, Memory consuming by forward 0.0000 MB
# batch: 32, Memory After backward 0.3708 MB
# batch: 32, Memory After optimizer step 0.3708 MB
# Epoch: 5/8 | Train loss: 25076916.0       | Val loss 29427182.0
# Begin epoch: 5
# batch: 0, memory Before forward 0.73 MB
# batch: 0, Memory After forward 0.74 MB
# batch: 0, Memory consuming by forward 0.0084 MB
# batch: 0, Memory After backward 0.7340 MB
# batch: 0, Memory After optimizer step 0.7340 MB
# batch: 1, memory Before forward 0.73 MB
# batch: 1, Memory After forward 0.74 MB
# batch: 1, Memory consuming by forward 0.0078 MB
# batch: 1, Memory After backward 0.7340 MB
# batch: 1, Memory After optimizer step 0.7340 MB
# batch: 2, memory Before forward 0.73 MB
# batch: 2, Memory After forward 0.74 MB
# batch: 2, Memory consuming by forward 0.0078 MB
# batch: 2, Memory After backward 0.7340 MB
# batch: 2, Memory After optimizer step 0.7340 MB
# batch: 3, memory Before forward 0.73 MB
# batch: 3, Memory After forward 0.74 MB
# batch: 3, Memory consuming by forward 0.0078 MB
# batch: 3, Memory After backward 0.7340 MB
# batch: 3, Memory After optimizer step 0.7340 MB
# batch: 4, memory Before forward 0.73 MB
# batch: 4, Memory After forward 0.38 MB
# batch: 4, Memory consuming by forward -0.3549 MB
# batch: 4, Memory After backward 0.3713 MB
# batch: 4, Memory After optimizer step 0.3713 MB
# batch: 5, memory Before forward 0.37 MB
# batch: 5, Memory After forward 0.38 MB
# batch: 5, Memory consuming by forward 0.0078 MB
# batch: 5, Memory After backward 0.3713 MB
# batch: 5, Memory After optimizer step 0.3713 MB
# batch: 6, memory Before forward 0.37 MB
# batch: 6, Memory After forward 0.38 MB
# batch: 6, Memory consuming by forward 0.0078 MB
# batch: 6, Memory After backward 0.3713 MB
# batch: 6, Memory After optimizer step 0.3713 MB
# batch: 7, memory Before forward 0.37 MB
# batch: 7, Memory After forward 0.38 MB
# batch: 7, Memory consuming by forward 0.0078 MB
# batch: 7, Memory After backward 0.3713 MB
# batch: 7, Memory After optimizer step 0.3713 MB
# batch: 8, memory Before forward 0.37 MB
# batch: 8, Memory After forward 0.38 MB
# batch: 8, Memory consuming by forward 0.0078 MB
# batch: 8, Memory After backward 0.3713 MB
# batch: 8, Memory After optimizer step 0.3713 MB
# batch: 9, memory Before forward 0.37 MB
# batch: 9, Memory After forward 0.38 MB
# batch: 9, Memory consuming by forward 0.0078 MB
# batch: 9, Memory After backward 0.3713 MB
# batch: 9, Memory After optimizer step 0.3713 MB
# batch: 10, memory Before forward 0.37 MB
# batch: 10, Memory After forward 0.38 MB
# batch: 10, Memory consuming by forward 0.0078 MB
# batch: 10, Memory After backward 0.3713 MB
# batch: 10, Memory After optimizer step 0.3713 MB
# batch: 11, memory Before forward 0.37 MB
# batch: 11, Memory After forward 0.38 MB
# batch: 11, Memory consuming by forward 0.0078 MB
# batch: 11, Memory After backward 0.3713 MB
# batch: 11, Memory After optimizer step 0.3713 MB
# batch: 12, memory Before forward 0.37 MB
# batch: 12, Memory After forward 0.38 MB
# batch: 12, Memory consuming by forward 0.0078 MB
# batch: 12, Memory After backward 0.3713 MB
# batch: 12, Memory After optimizer step 0.3713 MB
# batch: 13, memory Before forward 0.37 MB
# batch: 13, Memory After forward 0.38 MB
# batch: 13, Memory consuming by forward 0.0078 MB
# batch: 13, Memory After backward 0.3713 MB
# batch: 13, Memory After optimizer step 0.3713 MB
# batch: 14, memory Before forward 0.37 MB
# batch: 14, Memory After forward 0.38 MB
# batch: 14, Memory consuming by forward 0.0078 MB
# batch: 14, Memory After backward 0.3713 MB
# batch: 14, Memory After optimizer step 0.3713 MB
# batch: 15, memory Before forward 0.37 MB
# batch: 15, Memory After forward 0.38 MB
# batch: 15, Memory consuming by forward 0.0078 MB
# batch: 15, Memory After backward 0.3713 MB
# batch: 15, Memory After optimizer step 0.3713 MB
# batch: 16, memory Before forward 0.37 MB
# batch: 16, Memory After forward 0.38 MB
# batch: 16, Memory consuming by forward 0.0078 MB
# batch: 16, Memory After backward 0.3713 MB
# batch: 16, Memory After optimizer step 0.3713 MB
# batch: 17, memory Before forward 0.37 MB
# batch: 17, Memory After forward 0.38 MB
# batch: 17, Memory consuming by forward 0.0078 MB
# batch: 17, Memory After backward 0.3713 MB
# batch: 17, Memory After optimizer step 0.3713 MB
# batch: 18, memory Before forward 0.37 MB
# batch: 18, Memory After forward 0.38 MB
# batch: 18, Memory consuming by forward 0.0078 MB
# batch: 18, Memory After backward 0.3713 MB
# batch: 18, Memory After optimizer step 0.3713 MB
# batch: 19, memory Before forward 0.37 MB
# batch: 19, Memory After forward 0.38 MB
# batch: 19, Memory consuming by forward 0.0078 MB
# batch: 19, Memory After backward 0.3713 MB
# batch: 19, Memory After optimizer step 0.3713 MB
# batch: 20, memory Before forward 0.37 MB
# batch: 20, Memory After forward 0.38 MB
# batch: 20, Memory consuming by forward 0.0078 MB
# batch: 20, Memory After backward 0.3713 MB
# batch: 20, Memory After optimizer step 0.3713 MB
# batch: 21, memory Before forward 0.37 MB
# batch: 21, Memory After forward 0.38 MB
# batch: 21, Memory consuming by forward 0.0078 MB
# batch: 21, Memory After backward 0.3713 MB
# batch: 21, Memory After optimizer step 0.3713 MB
# batch: 22, memory Before forward 0.37 MB
# batch: 22, Memory After forward 0.38 MB
# batch: 22, Memory consuming by forward 0.0078 MB
# batch: 22, Memory After backward 0.3713 MB
# batch: 22, Memory After optimizer step 0.3713 MB
# batch: 23, memory Before forward 0.37 MB
# batch: 23, Memory After forward 0.38 MB
# batch: 23, Memory consuming by forward 0.0078 MB
# batch: 23, Memory After backward 0.3713 MB
# batch: 23, Memory After optimizer step 0.3713 MB
# batch: 24, memory Before forward 0.37 MB
# batch: 24, Memory After forward 0.38 MB
# batch: 24, Memory consuming by forward 0.0078 MB
# batch: 24, Memory After backward 0.3713 MB
# batch: 24, Memory After optimizer step 0.3713 MB
# batch: 25, memory Before forward 0.37 MB
# batch: 25, Memory After forward 0.38 MB
# batch: 25, Memory consuming by forward 0.0078 MB
# batch: 25, Memory After backward 0.3713 MB
# batch: 25, Memory After optimizer step 0.3713 MB
# batch: 26, memory Before forward 0.37 MB
# batch: 26, Memory After forward 0.38 MB
# batch: 26, Memory consuming by forward 0.0078 MB
# batch: 26, Memory After backward 0.3713 MB
# batch: 26, Memory After optimizer step 0.3713 MB
# batch: 27, memory Before forward 0.37 MB
# batch: 27, Memory After forward 0.38 MB
# batch: 27, Memory consuming by forward 0.0078 MB
# batch: 27, Memory After backward 0.3713 MB
# batch: 27, Memory After optimizer step 0.3713 MB
# batch: 28, memory Before forward 0.37 MB
# batch: 28, Memory After forward 0.38 MB
# batch: 28, Memory consuming by forward 0.0078 MB
# batch: 28, Memory After backward 0.3713 MB
# batch: 28, Memory After optimizer step 0.3713 MB
# batch: 29, memory Before forward 0.37 MB
# batch: 29, Memory After forward 0.38 MB
# batch: 29, Memory consuming by forward 0.0078 MB
# batch: 29, Memory After backward 0.3713 MB
# batch: 29, Memory After optimizer step 0.3713 MB
# batch: 30, memory Before forward 0.37 MB
# batch: 30, Memory After forward 0.38 MB
# batch: 30, Memory consuming by forward 0.0078 MB
# batch: 30, Memory After backward 0.3713 MB
# batch: 30, Memory After optimizer step 0.3713 MB
# batch: 31, memory Before forward 0.37 MB
# batch: 31, Memory After forward 0.38 MB
# batch: 31, Memory consuming by forward 0.0078 MB
# batch: 31, Memory After backward 0.3713 MB
# batch: 31, Memory After optimizer step 0.3713 MB
# batch: 32, memory Before forward 0.37 MB
# batch: 32, Memory After forward 0.37 MB
# batch: 32, Memory consuming by forward 0.0000 MB
# batch: 32, Memory After backward 0.3708 MB
# batch: 32, Memory After optimizer step 0.3708 MB
# Epoch: 6/8 | Train loss: 23485632.0       | Val loss 25686634.0
# Begin epoch: 6
# batch: 0, memory Before forward 0.73 MB
# batch: 0, Memory After forward 0.74 MB
# batch: 0, Memory consuming by forward 0.0084 MB
# batch: 0, Memory After backward 0.7340 MB
# batch: 0, Memory After optimizer step 0.7340 MB
# batch: 1, memory Before forward 0.73 MB
# batch: 1, Memory After forward 0.74 MB
# batch: 1, Memory consuming by forward 0.0078 MB
# batch: 1, Memory After backward 0.7340 MB
# batch: 1, Memory After optimizer step 0.7340 MB
# batch: 2, memory Before forward 0.73 MB
# batch: 2, Memory After forward 0.74 MB
# batch: 2, Memory consuming by forward 0.0078 MB
# batch: 2, Memory After backward 0.7340 MB
# batch: 2, Memory After optimizer step 0.7340 MB
# batch: 3, memory Before forward 0.73 MB
# batch: 3, Memory After forward 0.74 MB
# batch: 3, Memory consuming by forward 0.0078 MB
# batch: 3, Memory After backward 0.7340 MB
# batch: 3, Memory After optimizer step 0.7340 MB
# batch: 4, memory Before forward 0.73 MB
# batch: 4, Memory After forward 0.74 MB
# batch: 4, Memory consuming by forward 0.0078 MB
# batch: 4, Memory After backward 0.7340 MB
# batch: 4, Memory After optimizer step 0.7340 MB
# batch: 5, memory Before forward 0.73 MB
# batch: 5, Memory After forward 0.74 MB
# batch: 5, Memory consuming by forward 0.0078 MB
# batch: 5, Memory After backward 0.7340 MB
# batch: 5, Memory After optimizer step 0.7340 MB
# batch: 6, memory Before forward 0.73 MB
# batch: 6, Memory After forward 0.74 MB
# batch: 6, Memory consuming by forward 0.0078 MB
# batch: 6, Memory After backward 0.7340 MB
# batch: 6, Memory After optimizer step 0.7340 MB
# batch: 7, memory Before forward 0.73 MB
# batch: 7, Memory After forward 0.74 MB
# batch: 7, Memory consuming by forward 0.0078 MB
# batch: 7, Memory After backward 0.7340 MB
# batch: 7, Memory After optimizer step 0.7340 MB
# batch: 8, memory Before forward 0.73 MB
# batch: 8, Memory After forward 0.74 MB
# batch: 8, Memory consuming by forward 0.0078 MB
# batch: 8, Memory After backward 0.7340 MB
# batch: 8, Memory After optimizer step 0.7340 MB
# batch: 9, memory Before forward 0.73 MB
# batch: 9, Memory After forward 0.74 MB
# batch: 9, Memory consuming by forward 0.0078 MB
# batch: 9, Memory After backward 0.7340 MB
# batch: 9, Memory After optimizer step 0.7340 MB
# batch: 10, memory Before forward 0.73 MB
# batch: 10, Memory After forward 0.74 MB
# batch: 10, Memory consuming by forward 0.0078 MB
# batch: 10, Memory After backward 0.7340 MB
# batch: 10, Memory After optimizer step 0.7340 MB
# batch: 11, memory Before forward 0.73 MB
# batch: 11, Memory After forward 0.74 MB
# batch: 11, Memory consuming by forward 0.0078 MB
# batch: 11, Memory After backward 0.7340 MB
# batch: 11, Memory After optimizer step 0.7340 MB
# batch: 12, memory Before forward 0.73 MB
# batch: 12, Memory After forward 0.74 MB
# batch: 12, Memory consuming by forward 0.0078 MB
# batch: 12, Memory After backward 0.7340 MB
# batch: 12, Memory After optimizer step 0.7340 MB
# batch: 13, memory Before forward 0.73 MB
# batch: 13, Memory After forward 0.74 MB
# batch: 13, Memory consuming by forward 0.0078 MB
# batch: 13, Memory After backward 0.7340 MB
# batch: 13, Memory After optimizer step 0.3707 MB
# batch: 14, memory Before forward 0.37 MB
# batch: 14, Memory After forward 0.38 MB
# batch: 14, Memory consuming by forward 0.0084 MB
# batch: 14, Memory After backward 0.3713 MB
# batch: 14, Memory After optimizer step 0.3713 MB
# batch: 15, memory Before forward 0.37 MB
# batch: 15, Memory After forward 0.38 MB
# batch: 15, Memory consuming by forward 0.0078 MB
# batch: 15, Memory After backward 0.3713 MB
# batch: 15, Memory After optimizer step 0.3713 MB
# batch: 16, memory Before forward 0.37 MB
# batch: 16, Memory After forward 0.38 MB
# batch: 16, Memory consuming by forward 0.0078 MB
# batch: 16, Memory After backward 0.3713 MB
# batch: 16, Memory After optimizer step 0.3713 MB
# batch: 17, memory Before forward 0.37 MB
# batch: 17, Memory After forward 0.38 MB
# batch: 17, Memory consuming by forward 0.0078 MB
# batch: 17, Memory After backward 0.3713 MB
# batch: 17, Memory After optimizer step 0.3713 MB
# batch: 18, memory Before forward 0.37 MB
# batch: 18, Memory After forward 0.38 MB
# batch: 18, Memory consuming by forward 0.0078 MB
# batch: 18, Memory After backward 0.3713 MB
# batch: 18, Memory After optimizer step 0.3713 MB
# batch: 19, memory Before forward 0.37 MB
# batch: 19, Memory After forward 0.38 MB
# batch: 19, Memory consuming by forward 0.0078 MB
# batch: 19, Memory After backward 0.3713 MB
# batch: 19, Memory After optimizer step 0.3713 MB
# batch: 20, memory Before forward 0.37 MB
# batch: 20, Memory After forward 0.38 MB
# batch: 20, Memory consuming by forward 0.0078 MB
# batch: 20, Memory After backward 0.3713 MB
# batch: 20, Memory After optimizer step 0.3713 MB
# batch: 21, memory Before forward 0.37 MB
# batch: 21, Memory After forward 0.38 MB
# batch: 21, Memory consuming by forward 0.0078 MB
# batch: 21, Memory After backward 0.3713 MB
# batch: 21, Memory After optimizer step 0.3713 MB
# batch: 22, memory Before forward 0.37 MB
# batch: 22, Memory After forward 0.38 MB
# batch: 22, Memory consuming by forward 0.0078 MB
# batch: 22, Memory After backward 0.3713 MB
# batch: 22, Memory After optimizer step 0.3713 MB
# batch: 23, memory Before forward 0.37 MB
# batch: 23, Memory After forward 0.38 MB
# batch: 23, Memory consuming by forward 0.0078 MB
# batch: 23, Memory After backward 0.3713 MB
# batch: 23, Memory After optimizer step 0.3713 MB
# batch: 24, memory Before forward 0.37 MB
# batch: 24, Memory After forward 0.38 MB
# batch: 24, Memory consuming by forward 0.0078 MB
# batch: 24, Memory After backward 0.3713 MB
# batch: 24, Memory After optimizer step 0.3713 MB
# batch: 25, memory Before forward 0.37 MB
# batch: 25, Memory After forward 0.38 MB
# batch: 25, Memory consuming by forward 0.0078 MB
# batch: 25, Memory After backward 0.3713 MB
# batch: 25, Memory After optimizer step 0.3713 MB
# batch: 26, memory Before forward 0.37 MB
# batch: 26, Memory After forward 0.38 MB
# batch: 26, Memory consuming by forward 0.0078 MB
# batch: 26, Memory After backward 0.3713 MB
# batch: 26, Memory After optimizer step 0.3713 MB
# batch: 27, memory Before forward 0.37 MB
# batch: 27, Memory After forward 0.38 MB
# batch: 27, Memory consuming by forward 0.0078 MB
# batch: 27, Memory After backward 0.3713 MB
# batch: 27, Memory After optimizer step 0.3713 MB
# batch: 28, memory Before forward 0.37 MB
# batch: 28, Memory After forward 0.38 MB
# batch: 28, Memory consuming by forward 0.0078 MB
# batch: 28, Memory After backward 0.3713 MB
# batch: 28, Memory After optimizer step 0.3713 MB
# batch: 29, memory Before forward 0.37 MB
# batch: 29, Memory After forward 0.38 MB
# batch: 29, Memory consuming by forward 0.0078 MB
# batch: 29, Memory After backward 0.3713 MB
# batch: 29, Memory After optimizer step 0.3713 MB
# batch: 30, memory Before forward 0.37 MB
# batch: 30, Memory After forward 0.38 MB
# batch: 30, Memory consuming by forward 0.0078 MB
# batch: 30, Memory After backward 0.3713 MB
# batch: 30, Memory After optimizer step 0.3713 MB
# batch: 31, memory Before forward 0.37 MB
# batch: 31, Memory After forward 0.38 MB
# batch: 31, Memory consuming by forward 0.0078 MB
# batch: 31, Memory After backward 0.3713 MB
# batch: 31, Memory After optimizer step 0.3713 MB
# batch: 32, memory Before forward 0.37 MB
# batch: 32, Memory After forward 0.37 MB
# batch: 32, Memory consuming by forward 0.0000 MB
# batch: 32, Memory After backward 0.3708 MB
# batch: 32, Memory After optimizer step 0.3708 MB
# Epoch: 7/8 | Train loss: 22088746.0       | Val loss 25433500.0
# Begin epoch: 7
# batch: 0, memory Before forward 0.37 MB
# batch: 0, Memory After forward 0.38 MB
# batch: 0, Memory consuming by forward 0.0084 MB
# batch: 0, Memory After backward 0.3713 MB
# batch: 0, Memory After optimizer step 0.3713 MB
# batch: 1, memory Before forward 0.37 MB
# batch: 1, Memory After forward 0.38 MB
# batch: 1, Memory consuming by forward 0.0078 MB
# batch: 1, Memory After backward 0.3713 MB
# batch: 1, Memory After optimizer step 0.3713 MB
# batch: 2, memory Before forward 0.37 MB
# batch: 2, Memory After forward 0.38 MB
# batch: 2, Memory consuming by forward 0.0078 MB
# batch: 2, Memory After backward 0.3713 MB
# batch: 2, Memory After optimizer step 0.3713 MB
# batch: 3, memory Before forward 0.37 MB
# batch: 3, Memory After forward 0.38 MB
# batch: 3, Memory consuming by forward 0.0078 MB
# batch: 3, Memory After backward 0.3713 MB
# batch: 3, Memory After optimizer step 0.3713 MB
# batch: 4, memory Before forward 0.37 MB
# batch: 4, Memory After forward 0.38 MB
# batch: 4, Memory consuming by forward 0.0078 MB
# batch: 4, Memory After backward 0.3713 MB
# batch: 4, Memory After optimizer step 0.3713 MB
# batch: 5, memory Before forward 0.37 MB
# batch: 5, Memory After forward 0.38 MB
# batch: 5, Memory consuming by forward 0.0078 MB
# batch: 5, Memory After backward 0.3713 MB
# batch: 5, Memory After optimizer step 0.3713 MB
# batch: 6, memory Before forward 0.37 MB
# batch: 6, Memory After forward 0.38 MB
# batch: 6, Memory consuming by forward 0.0078 MB
# batch: 6, Memory After backward 0.3713 MB
# batch: 6, Memory After optimizer step 0.3713 MB
# batch: 7, memory Before forward 0.37 MB
# batch: 7, Memory After forward 0.38 MB
# batch: 7, Memory consuming by forward 0.0078 MB
# batch: 7, Memory After backward 0.3713 MB
# batch: 7, Memory After optimizer step 0.3713 MB
# batch: 8, memory Before forward 0.37 MB
# batch: 8, Memory After forward 0.38 MB
# batch: 8, Memory consuming by forward 0.0078 MB
# batch: 8, Memory After backward 0.3713 MB
# batch: 8, Memory After optimizer step 0.3713 MB
# batch: 9, memory Before forward 0.37 MB
# batch: 9, Memory After forward 0.38 MB
# batch: 9, Memory consuming by forward 0.0078 MB
# batch: 9, Memory After backward 0.3713 MB
# batch: 9, Memory After optimizer step 0.3713 MB
# batch: 10, memory Before forward 0.37 MB
# batch: 10, Memory After forward 0.38 MB
# batch: 10, Memory consuming by forward 0.0078 MB
# batch: 10, Memory After backward 0.3713 MB
# batch: 10, Memory After optimizer step 0.3713 MB
# batch: 11, memory Before forward 0.37 MB
# batch: 11, Memory After forward 0.38 MB
# batch: 11, Memory consuming by forward 0.0078 MB
# batch: 11, Memory After backward 0.3713 MB
# batch: 11, Memory After optimizer step 0.3713 MB
# batch: 12, memory Before forward 0.37 MB
# batch: 12, Memory After forward 0.38 MB
# batch: 12, Memory consuming by forward 0.0078 MB
# batch: 12, Memory After backward 0.3713 MB
# batch: 12, Memory After optimizer step 0.3713 MB
# batch: 13, memory Before forward 0.37 MB
# batch: 13, Memory After forward 0.38 MB
# batch: 13, Memory consuming by forward 0.0078 MB
# batch: 13, Memory After backward 0.3713 MB
# batch: 13, Memory After optimizer step 0.3713 MB
# batch: 14, memory Before forward 0.37 MB
# batch: 14, Memory After forward 0.38 MB
# batch: 14, Memory consuming by forward 0.0078 MB
# batch: 14, Memory After backward 0.3713 MB
# batch: 14, Memory After optimizer step 0.3713 MB
# batch: 15, memory Before forward 0.37 MB
# batch: 15, Memory After forward 0.38 MB
# batch: 15, Memory consuming by forward 0.0078 MB
# batch: 15, Memory After backward 0.3713 MB
# batch: 15, Memory After optimizer step 0.3713 MB
# batch: 16, memory Before forward 0.37 MB
# batch: 16, Memory After forward 0.38 MB
# batch: 16, Memory consuming by forward 0.0078 MB
# batch: 16, Memory After backward 0.3713 MB
# batch: 16, Memory After optimizer step 0.3713 MB
# batch: 17, memory Before forward 0.37 MB
# batch: 17, Memory After forward 0.38 MB
# batch: 17, Memory consuming by forward 0.0078 MB
# batch: 17, Memory After backward 0.3713 MB
# batch: 17, Memory After optimizer step 0.3713 MB
# batch: 18, memory Before forward 0.37 MB
# batch: 18, Memory After forward 0.38 MB
# batch: 18, Memory consuming by forward 0.0078 MB
# batch: 18, Memory After backward 0.3713 MB
# batch: 18, Memory After optimizer step 0.3713 MB
# batch: 19, memory Before forward 0.37 MB
# batch: 19, Memory After forward 0.38 MB
# batch: 19, Memory consuming by forward 0.0078 MB
# batch: 19, Memory After backward 0.3713 MB
# batch: 19, Memory After optimizer step 0.3713 MB
# batch: 20, memory Before forward 0.37 MB
# batch: 20, Memory After forward 0.38 MB
# batch: 20, Memory consuming by forward 0.0078 MB
# batch: 20, Memory After backward 0.3713 MB
# batch: 20, Memory After optimizer step 0.3713 MB
# batch: 21, memory Before forward 0.37 MB
# batch: 21, Memory After forward 0.38 MB
# batch: 21, Memory consuming by forward 0.0078 MB
# batch: 21, Memory After backward 0.3713 MB
# batch: 21, Memory After optimizer step 0.3713 MB
# batch: 22, memory Before forward 0.37 MB
# batch: 22, Memory After forward 0.38 MB
# batch: 22, Memory consuming by forward 0.0078 MB
# batch: 22, Memory After backward 0.3713 MB
# batch: 22, Memory After optimizer step 0.3713 MB
# batch: 23, memory Before forward 0.37 MB
# batch: 23, Memory After forward 0.38 MB
# batch: 23, Memory consuming by forward 0.0078 MB
# batch: 23, Memory After backward 0.3713 MB
# batch: 23, Memory After optimizer step 0.3713 MB
# batch: 24, memory Before forward 0.37 MB
# batch: 24, Memory After forward 0.38 MB
# batch: 24, Memory consuming by forward 0.0084 MB
# batch: 24, Memory After backward 0.3713 MB
# batch: 24, Memory After optimizer step 0.3713 MB
# batch: 25, memory Before forward 0.37 MB
# batch: 25, Memory After forward 0.38 MB
# batch: 25, Memory consuming by forward 0.0078 MB
# batch: 25, Memory After backward 0.3713 MB
# batch: 25, Memory After optimizer step 0.3713 MB
# batch: 26, memory Before forward 0.37 MB
# batch: 26, Memory After forward 0.38 MB
# batch: 26, Memory consuming by forward 0.0078 MB
# batch: 26, Memory After backward 0.3713 MB
# batch: 26, Memory After optimizer step 0.3713 MB
# batch: 27, memory Before forward 0.37 MB
# batch: 27, Memory After forward 0.38 MB
# batch: 27, Memory consuming by forward 0.0078 MB
# batch: 27, Memory After backward 0.3713 MB
# batch: 27, Memory After optimizer step 0.3713 MB
# batch: 28, memory Before forward 0.37 MB
# batch: 28, Memory After forward 0.38 MB
# batch: 28, Memory consuming by forward 0.0078 MB
# batch: 28, Memory After backward 0.3713 MB
# batch: 28, Memory After optimizer step 0.3713 MB
# batch: 29, memory Before forward 0.37 MB
# batch: 29, Memory After forward 0.38 MB
# batch: 29, Memory consuming by forward 0.0078 MB
# batch: 29, Memory After backward 0.3713 MB
# batch: 29, Memory After optimizer step 0.3713 MB
# batch: 30, memory Before forward 0.37 MB
# batch: 30, Memory After forward 0.38 MB
# batch: 30, Memory consuming by forward 0.0078 MB
# batch: 30, Memory After backward 0.3713 MB
# batch: 30, Memory After optimizer step 0.3713 MB
# batch: 31, memory Before forward 0.37 MB
# batch: 31, Memory After forward 0.38 MB
# batch: 31, Memory consuming by forward 0.0078 MB
# batch: 31, Memory After backward 0.3713 MB
# batch: 31, Memory After optimizer step 0.3713 MB
# batch: 32, memory Before forward 0.37 MB
# batch: 32, Memory After forward 0.37 MB
# batch: 32, Memory consuming by forward 0.0000 MB
# batch: 32, Memory After backward 0.3708 MB
# batch: 32, Memory After optimizer step 0.3708 MB
# Epoch: 8/8 | Train loss: 21136000.0       | Val loss 22561320.0
# CPU times: user 2.47 s, sys: 379 ms, total: 2.85 s
# Wall time: 2.6 s

# %%
plt.figure(figsize = (8,6))
plt.plot(train_losses[50:])
plt.plot(val_losses[50:], '-k')
plt.title('Training-Validation loss', fontsize = 16)
plt.grid()
plt.legend(['Training loss','Validation loss'])

# %% [markdown]
# # Evalute on the test data

# %% [markdown]
# ### Scale the test data before evaluating the model

# %%
Test_scaler_x = preprocessing.MinMaxScaler(feature_range=feature_range).fit(X_test) # maybe try another for X?
X_Test_scaled = Test_scaler_x.transform(X_test)

predictions = model(torch.tensor(X_Test_scaled).float().to(device)).cpu().detach().numpy()
test_targets = y_test.values

# %%
for idx, ch in enumerate(df.columns.tolist()[8:]):
  # issues with 2 and 7
    plt.figure(idx, figsize = (8,6))
    sns.scatterplot(x = predictions[:,idx], y = test_targets[:,idx])
    plt.title(f'DELs: {ch}', fontsize = 20)
    plt.xlabel('Predictions [kNm]', fontsize = 12)
    plt.ylabel('Targets [kNm]')

# %%
mse_list = []
r2_score_list = []
for i in range(len(df.columns.tolist()[8:])):
    #print(f'MSE {AllTargetData.columns[i]} Channel : \n {mean_squared_error(AllTargetData.values[:,i], Yout[:,i])}')
    mse_list.append(mean_squared_error(test_targets[:,i], predictions[:,i]))
    r2_score_list.append(r2_score(test_targets[:,i], predictions[:,i]))
 

 # Compute the normalized mean square error:
Norm_RMSE = np.sqrt(np.array(mse_list)) / y_test.describe().loc['mean'].values

# %%
fig = plt.figure(figsize= (10,4)) 
sns.barplot(x= df.columns.tolist()[8:], y= r2_score_list) 
plt.ylim([min(r2_score_list)*0.92,max(r2_score_list)*1.02])
plt.ylabel('R2 score', fontsize = 20)
plt.grid()

# %%
fig = plt.figure(figsize= (10,4)) 
sns.barplot(x= df.columns.tolist()[8:], y= Norm_RMSE) 
plt.ylim([0,max(Norm_RMSE)*1.02])
plt.ylabel('Normalized Root Mean Square Error', fontsize = 20)
plt.grid()

# %% [markdown]
# # ============================================================
# # ==========================Section 2 ==========================
# # ============================================================
# ### Compare versus the wind2loads neural net

# %%
error on purpose

# %%
from w2l import neuralnets

# %%
# define the model using the same net architecture, and train for the same number of epochs using the previously batch size as well.
w2l_net = neuralnets.ann(layersizes = [input_size, num_hid_1, num_hid_2, output_channels],
                       params = {'minibatchsize':64, 'nepochs':500}, 
                       output_style = 'None',
                        testratios = [0.7, 0.3, 0.])

# %%
# train using the data from the first split
Outdata = w2l_net.train(X.values,y.values)

# %%
w2l_net.params

# %%
Outdata.keys()

# %% [markdown]
# $\color{red}{\text{Why 500 epochs tho}}$

# %%
plt.plot(Outdata['Jhist'][50:])

# %%
Yout = w2l_net.predict(X_test.values)

# %%
for idx, ch in enumerate(df.columns.tolist()[8:]):
  # issues with 2 and 7
    plt.figure(idx, figsize = (8,6))
    sns.scatterplot(Yout[:,idx],test_targets[:,idx])
    sns.scatterplot(predictions[:,idx],test_targets[:,idx])
    plt.title(f'DELs: {ch}', fontsize = 20)
    plt.legend(['W2L','PyTorch'])
    plt.xlabel('Predictions [kNm]', fontsize = 12)
    plt.ylabel('Targets [kNm]')

# %%
W2L_mse_list = []
W2L_r2_score_list = []
for i in range(len(df.columns.tolist()[8:])):
    #print(f'MSE {AllTargetData.columns[i]} Channel : \n {mean_squared_error(AllTargetData.values[:,i], Yout[:,i])}')
    W2L_mse_list.append(mean_squared_error(test_targets[:,i], Yout[:,i]))
    W2L_r2_score_list.append(r2_score(test_targets[:,i], Yout[:,i]))
    
W2L_Norm_RMSE = np.sqrt(np.array(W2L_mse_list)) / y_test.describe().loc['mean'].values

# %%
fig = plt.figure(figsize= (12,6)) 
sns.barplot(x= df.columns.tolist()[8:], y= W2L_r2_score_list) 
plt.ylim([min(W2L_r2_score_list)*0.92,max(W2L_r2_score_list)*1.02])
plt.ylabel('R2 score', fontsize = 20)
plt.grid()

# %% [markdown]
# # Compare Wind2Loads net versus PyTorch implementation

# %%
barplot_lst = []
for i,ch in enumerate(df.columns.tolist()[8:]):
    barplot_lst.append(['pytorch',ch,r2_score_list[i]])
for i,ch in enumerate(df.columns.tolist()[8:]):
    barplot_lst.append(['W2L',ch,W2L_r2_score_list[i]])

# %%
df_comparison = pd.DataFrame(barplot_lst,
                  columns=['Model','channel','r2'])

# %%
plt.figure(figsize=(12,6))
df_comparison.pivot("channel", "Model", "r2").plot(kind='bar')
plt.ylim([min(r2_score_list)*0.98,max(r2_score_list)*1.02])
plt.title('R2', fontsize = 18)
plt.show()

# %%
barplot_lst_NMSE = []
for i,ch in enumerate(df.columns.tolist()[8:]):
    barplot_lst_NMSE.append(['pytorch',ch , Norm_RMSE[i]])
for i,ch in enumerate(df.columns.tolist()[8:]):
    barplot_lst_NMSE.append(['W2L', ch, W2L_Norm_RMSE[i]])

# %%
df_NRMSE_comparison = pd.DataFrame(barplot_lst_NMSE,
                  columns=['Model','channel','NRMSE'])

# %%
plt.figure(figsize=(14,6))
df_NRMSE_comparison.pivot("channel", "Model", "NRMSE").plot(kind='bar')
plt.ylim([0,max(W2L_Norm_RMSE)*1.02])
plt.show()
